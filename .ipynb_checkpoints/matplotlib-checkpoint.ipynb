# %% [markdown]
# # Line Plot

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
cols = ['date', 'close', 'high', 'low', 'open']
df = pd.read_csv("AAPL.csv", index_col="date", usecols=cols, parse_dates=["date"])
df
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.loc["2016-5"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(y="close")
# Out:
# <Axes: xlabel='date'>

# %%
df.loc["2016-5"].plot(y=["close", "open"])
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(subplots=True, figsize=[10,15])
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
df.plot()
plt.title("Apple Stocks")
plt.xlabel("Year")
plt.ylabel("Price")
plt.legend(loc="best")
plt.grid()

# %%
df.loc["2016-5"].plot(y="close", c="b", linewidth=4, linestyle=":")
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Bar Plot

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
cols = ['date', 'close', 'high', 'low', 'open']
df = pd.read_csv("AAPL.csv", index_col="date", usecols=cols, parse_dates=["date"])
df
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
years = df.resample("a").mean().round(2)
years.index = years.index.year
years
# Out:
#        close    high     low    open
# date
# 2015  117.83  119.03  116.65  117.93
# 2016  104.60  105.43  103.69  104.51
# 2017  150.55  151.41  149.49  150.45
# 2018  189.05  190.99  187.18  189.11
# 2019  208.26  209.83  206.27  207.87
# 2020  291.79  295.89  287.02  290.75

# %%
years.plot(y="high", kind="bar", xlabel="Year")
# Out:
# <Axes: xlabel='Year'>

# %%
years.plot(y="high", kind="barh", xlabel="Year")
# Out:
# <Axes: xlabel='Year', ylabel='date'>

# %%
years.plot(y=["high", "low"], kind="bar", color=["green", "red"], xlabel="Year")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Histogram

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("exams.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch
# 0    male        group A                 high school      standard  \
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
df["total"] = df["math score"] + df["reading score"] + df["writing score"]
df
# Out:
#      gender race/ethnicity parental level of education         lunch
# 0      male        group A                 high school      standard  \
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
df.plot(y="total", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(y="total", kind="hist", bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["total"].hist(grid=False, color="skyblue")
# Out:
# <Axes: >

# %% [markdown]
# # Pie Charts

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("TopRichestInWorld.csv")
df
# Out:
#                          Name          NetWorth  Age Country/Territory
# 0                   Elon Musk  $219,000,000,000   50     United States  \
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
industries = df.Industry.value_counts()
industries
# Out:
# Industry
# Fashion & Retail         18
# Technology               15
# Finance & Investments    13
# Metals & Mining           9
# Food & Beverage           8
# Automotive                7
# Diversified               6
# Manufacturing             5
# Healthcare                5
# Media & Entertainment     4
# Real Estate               3
# Telecom                   2
# Logistics                 2
# Energy                    2
# Gambling & Casinos        1
# Service                   1
# Name: count, dtype: int64

# %%
plt.pie(x=industries, labels=industries.index)
plt.show()

# %%
labels = industries.index[:10]
values = industries.values[:10]
plt.pie(x=values, labels=labels, autopct="%.2f%%")
plt.show()

# %%
plt.pie(x=values, labels=labels, colors = ["darkblue", "skyblue"], autopct="%.0f")
plt.show()

# %% [markdown]
# # Styles

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Pokemon.csv", index_col="#")
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49  \
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
poke_groups = df.groupby(by="Type 1")
max_attack = poke_groups["Attack"].max()

# %%
max_attack.sort_values().plot(kind="barh", color=("skyblue", "crimson"))
# Out:
# <Axes: ylabel='Type 1'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("grayscale")
max_attack.plot(kind="barh")
# Out:
# <Axes: ylabel='Type 1'>

# %%
plt.style.use("dark_background")
max_attack.plot(kind="barh")
# Out:
# <Axes: ylabel='Type 1'>

# %%
for style in plt.style.available:
    plt.style.use(style)
    print(style)
    max_attack.plot(kind="barh", figsize=(4,3), fontsize=6)
    plt.show()
# Out:
# Solarize_Light2
# _classic_test_patch
# _mpl-gallery
# _mpl-gallery-nogrid
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn-v0_8
# seaborn-v0_8-bright
# seaborn-v0_8-colorblind
# seaborn-v0_8-dark
# seaborn-v0_8-dark-palette
# seaborn-v0_8-darkgrid
# seaborn-v0_8-deep
# seaborn-v0_8-muted
# seaborn-v0_8-notebook
# seaborn-v0_8-paper
# seaborn-v0_8-pastel
# seaborn-v0_8-poster
# seaborn-v0_8-talk
# seaborn-v0_8-ticks
# seaborn-v0_8-white
# seaborn-v0_8-whitegrid
# tableau-colorblind10

# %% [markdown]
# # Scatter

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Pokemon.csv", index_col="#")
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49  \
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df.plot(x="Defense", y="Attack", kind="scatter")
plt.show()

# %%
df.plot(x="Generation", y="Attack", kind="scatter", color="crimson")
# Out:
# <Axes: xlabel='Generation', ylabel='Attack'>

# %% [markdown]
# # Candlestick Charts

# %%
# %pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Users\emirk\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import mplfinance as mpf

# %%
cols = ['date', 'close', 'high', 'low', 'open', "volume"]
df = pd.read_csv("AAPL.csv", index_col="date", usecols=cols, parse_dates=["date"])
df
# Out:
#                              close     high       low    open    volume
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34  45833246
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86  30733309
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23  50884452
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20  32112797
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86  33667627
# ...                            ...      ...       ...     ...       ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17  33843125
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03  25432385
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68  27876215
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66  25672211
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77  20450754
#
# [1258 rows x 5 columns]

# %%
year_2016 = df.loc["2016-01":"2016-12"]
mpf.plot(year_2016, type="candlestick", style="yahoo", title="AAPLUSD", ylabel="USD $")

# %%
mpf.plot(year_2016, type="candlestick", style="yahoo", title="AAPLUSD", ylabel="USD $", volume=True)

# %%
mpf.plot(df.loc["2020-01":"2020-04"], type="candlestick", style="yahoo", title="AAPLUSD", ylabel="USD $")

# %% [markdown]
# # Color by Value

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("gap.csv", usecols=["Country", "City", "AQI Value", "AQI Category"])
df
# Out:
#                         Country              City  AQI Value AQI Category
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
# [23463 rows x 4 columns]

# %%
df.sort_values(by="AQI Value", inplace=True)
df
# Out:
#                                 Country        City  AQI Value AQI Category
# 512    Bolivia (Plurinational State of)    El Torno          6         Good
# 9194                            Ecuador       Macas          7         Good
# 23269                  Papua New Guinea        Tari          8         Good
# 14502                           Ecuador     Azogues          8         Good
# 7486                               Peru      Huaraz          9         Good
# ...                                 ...         ...        ...          ...
# 2773                              India    Bisalpur        500    Hazardous
# 20585                             India     Pokaran        500    Hazardous
# 19572                             India  Ganganagar        500    Hazardous
# 17141                             India   Pilibanga        500    Hazardous
# 6657                              India       Churu        500    Hazardous
#
# [23463 rows x 4 columns]

# %%
countries = df.groupby("Country")

# %%
average = countries.mean(numeric_only=True).round(2)
average
# Out:
#                                     AQI Value
# Country
# Afghanistan                             95.96
# Albania                                 68.25
# Algeria                                 88.17
# Andorra                                 29.33
# Angola                                  83.93
# ...                                       ...
# Venezuela (Bolivarian Republic of)      77.72
# Viet Nam                                87.05
# Yemen                                  144.57
# Zambia                                  40.67
# Zimbabwe                                43.74
#
# [175 rows x 1 columns]

# %%
average.sort_values(by="AQI Value", inplace=True)
average
# Out:
#                                   AQI Value
# Country
# Palau                                 16.00
# Solomon Islands                       18.00
# Maldives                              19.00
# Iceland                               23.00
# Bolivia (Plurinational State of)      23.79
# ...                                     ...
# United Arab Emirates                 163.67
# Pakistan                             178.79
# Mauritania                           179.00
# Bahrain                              188.00
# Republic of Korea                    421.00
#
# [175 rows x 1 columns]

# %%
def value2color(value):
    if value<50:
        return "forestgreen"
    elif value<100:
        return "orange"
    else:
        return "crimson"

# %%
colors = average["AQI Value"].apply(value2color)
colors
# Out:
# Country
# Palau                               forestgreen
# Solomon Islands                     forestgreen
# Maldives                            forestgreen
# Iceland                             forestgreen
# Bolivia (Plurinational State of)    forestgreen
#                                        ...
# United Arab Emirates                    crimson
# Pakistan                                crimson
# Mauritania                              crimson
# Bahrain                                 crimson
# Republic of Korea                       crimson
# Name: AQI Value, Length: 175, dtype: object

# %%
average.plot(y="AQI Value", color=colors, kind="barh", figsize=(10,40))
# Out:
# <Axes: ylabel='Country'>

# %%
turkey = countries.get_group("Turkey")
turkey
# Out:
#       Country    City  AQI Value                    AQI Category
# 3257   Turkey  Turhal         26                            Good
# 7085   Turkey  Inegol         27                            Good
# 1516   Turkey   Cumra         30                            Good
# 1036   Turkey  Gorele         31                            Good
# 16146  Turkey     Cay         32                            Good
# ...       ...     ...        ...                             ...
# 2553   Turkey  Silvan         90                        Moderate
# 16882  Turkey    Tire         91                        Moderate
# 12102  Turkey    Soke         94                        Moderate
# 1151   Turkey   Nizip        112  Unhealthy for Sensitive Groups
# 6659   Turkey   Cizre        121  Unhealthy for Sensitive Groups
#
# [241 rows x 4 columns]

# %%
colors = turkey["AQI Value"].apply(value2color)
colors
# Out:
# 3257     forestgreen
# 7085     forestgreen
# 1516     forestgreen
# 1036     forestgreen
# 16146    forestgreen
#             ...
# 2553          orange
# 16882         orange
# 12102         orange
# 1151         crimson
# 6659         crimson
# Name: AQI Value, Length: 241, dtype: object

# %%
turkey.plot(y="AQI Value", x="City", kind="barh", figsize=(10,40), color=colors)
plt.show()

# %%
from matplotlib.patches import Patch

# %%
good = Patch(color="forestgreen", label="Good")
ok = Patch(color="orange", label="Ok")
bad = Patch(color="crimson", label="Bad")

# %%
turkey.plot(y="AQI Value", x="City", kind="barh", figsize=(10,50), color=colors)
plt.legend(handles=[good, ok, bad])
plt.show()

# %% [markdown]
# # Interactive Plots

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib notebook

# %%
cols = ['date', 'close', 'high', 'low', 'open']
df = pd.read_csv("AAPL.csv", index_col="date", usecols=cols, parse_dates=["date"])
df
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
df.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
